# %%
! pip freeze | grep sentence
# Out:
# sentence-transformers==4.1.0
# sentencepiece==0.2.0

# %% [markdown]
# - Install sentence-transformers
#   - colab comes with preinstalled sentece-transformers
#
# - Popular pre-trained models
#   - all-MiniLM-L6-v2 – Fast and lightweight
#   - paraphrase-MiniLM-L6-v2
#   - multi-qa-MiniLM-L6-cos-v1 – Good for question-answering
#   - distiluse-base-multilingual-cased-v1 – Supports 15+ languages (including Malayalam!)
#
# - even for more than one sentence it generate a fixed size encoding

# %%
import torch
torch.backends.mps.is_available()
# Out:
# True

# %%
from sentence_transformers import SentenceTransformer
import torch

model = SentenceTransformer('all-MiniLM-L6-v2')
# device = 'cuda' if torch.cuda.is_available() else 'cpu'
device = 'mps' if torch.backends.mps.is_available() else 'cpu'
model.to(device)

# sentences = ["This is an example sentence", "Each sentence is converted"]

# embeddings = model.encode(sentences, device=device)

# print(embeddings.shape)  # (2, 384)
# Out:
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 256, 'do_lower_case': False, 'architecture': 'BertModel'})
#   (1): Pooling({'word_embedding_dimension': 384, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
#   (2): Normalize()
# )

# %%
def cosine_similarity(x, y):
  x = F.normalize(x, p=2, dim=1) # p=2 Euclidien distance
  y = F.normalize(y, p=2, dim=1)
  return F.cosine_similarity(x, y, dim=1)

# %%
from sentence_transformers import util
import pandas as pd
import torch.nn.functional as F

file_name = 'train.csv'

df = pd.read_csv(file_name, engine='python')
print(df.head())

sentences_1 = df.question1.tolist()
sentences_2 = df.question2.tolist()

encoded_1 = model.encode(
    sentences_1,
    show_progress_bar=True,
    normalize_embeddings=True,
    convert_to_tensor=True,
    device=device
    )

print(f'encoded shape: {encoded_1.shape}')

encoded_2 = model.encode(
    sentences_2,
    show_progress_bar=True,
    normalize_embeddings=True,
    convert_to_tensor=True,
    device=device
    )

encoded_1.to(device)
encoded_2.to(device)

similarity_scores = cosine_similarity(encoded_1, encoded_2)
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate
# 0  What is the step by step guide to invest in sh...             0
# 1  What would happen if the Indian government sto...             0
# 2  How can Internet speed be increased by hacking...             0
# 3  Find the remainder when [math]23^{24}[/math] i...             0
# 4            Which fish would survive in salt water?             0
# Batches:   0%|          | 0/12635 [00:00<?, ?it/s]
# encoded shape: torch.Size([404290, 384])
# Batches:   0%|          | 0/12635 [00:00<?, ?it/s]

# %%
df['similarity_scores'] = similarity_scores.tolist()
df.to_csv('train_with_similarity_scores.csv', index=False)

# %%
df.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate  \
# 0  What is the step by step guide to invest in sh...             0
# 1  What would happen if the Indian government sto...             0
# 2  How can Internet speed be increased by hacking...             0
# 3  Find the remainder when [math]23^{24}[/math] i...             0
# 4            Which fish would survive in salt water?             0
#
#    similarity_scores
# 0           0.912277
# 1           0.655141
# 2           0.515561
# 3           0.104022
# 4           0.325348

# %%
df['clculated_similarity'] = df.apply(
    lambda x: 1 if x['similarity_scores'] > 0.75 else 0,
    axis=1
)

diff_df = df.loc[df['clculated_similarity'] != df['is_duplicate']]
diff_df.to_csv('diff_df.csv', index=False)

# %%
# from google.colab import files

# files.download('train_with_similarity_scores.csv')
diff_df.head()
# Out:
#     id  qid1  qid2                                          question1  \
# 0    0     1     2  What is the step by step guide to invest in sh...
# 14  14    29    30  What are the laws to change your status from a...
# 15  15    31    32  What would a Trump presidency mean for current...
# 21  21    43    44              What's causing someone to be jealous?
# 25  25    51    52  What are some tips on making it through the jo...
#
#                                             question2  is_duplicate  \
# 0   What is the step by step guide to invest in sh...             0
# 14  What are the laws to change your status from a...             0
# 15  How will a Trump presidency affect the student...             1
# 21   What can I do to avoid being jealous of someone?             0
# 25  What are some tips on making it through the jo...             0
#
#     similarity_scores  clculated_similarity
# 0            0.912277                     1
# 14           0.792194                     1
# 15           0.662187                     0
# 21           0.773075                     1
# 25           0.828949                     1

# %%
from sklearn.metrics import confusion_matrix, f1_score

confusion_matrix(
    df['is_duplicate'],
    df['clculated_similarity'],
    normalize= 'true'
    )
# Out:
# array([[0.70876025, 0.29123975],
#        [0.12695712, 0.87304288]])

# %%
f1_score(df['is_duplicate'], df['clculated_similarity'])
# Out:
# 0.7365437332202911

# %% [markdown]
# ## Training a S-BERT Model
#
# ### Prepare training data
# ```
# from sentence_transformers import InputExample
# train_examples = [
#   InputExample(texts=["How to learn Python?", "What's the best way to learn Python?"], label=1.0),
#   InputExample(texts=["What is AI?", "How to bake a cake?"], label=0.0),
# ]
# ```
#
# ### Load pretrained S-BERT model
# ```
# from sentence_transformers import SentenceTransformer`
# model = SentenceTransformer('all-MiniLM-L6-v2')
# ```
#
# ### Choose a Loss Function
# - `CosineSimilarityLoss`: For similarity regression (labels: 0.0–1.0)
# - `ContrastiveLoss` / `TripletLoss`: For contrastive
# - `MultipleNegativesRankingLoss`: For large-scale retrieval
# - `SoftmaxLoss`: For classification
#
# ```
# from sentence_transformers import losses
#
# train_loss = losses.CosineSimilarityLoss(model)
# ```
#
# ### Train the Model
# ```
# model.fit(
#     train_objectives=[(train_dataloader, train_loss)],
#     epochs=1,
#     warmup_steps=100,
#     show_progress_bar=True
# )
# ```
#
# ### Save the model
# ```
# model.save('output/sbert-finetuned-model')
# ```
#
# ### Use the Model
# ```
# model = SentenceTransformer('output/sbert-finetuned-model')
# embeddings = model.encode(["Your sentence here"])
# ```

# %% [markdown]
# ## Generator to generate data to the Model
# - memory management
# - limited data is loaded to memory

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer, InputExample, losses
from torch.utils.data import IterableDataset, DataLoader
import torch.nn.functional as F
from datasets import Dataset

EPOCHS = 1

def input_exampe_generator(csv_path, chunk_size=10000):
  """
  Generator to yield input examples from a CSV file
  """
  chunk = pd.read_csv(csv_path, chunksize=chunk_size)
  for df in chunk:
    for index, row in df.iterrows():
      if pd.notnull(row['question1']) and pd.notnull(row['question2']):
        yield InputExample(
            texts=[str(row['question1']), str(row['question2'])],
            label=float(row['is_duplicate'])
        )

class SBERTInputDataset(IterableDataset):
  def __init__(self, csv_path):
    self.csv_path = csv_path

  def __iter__(self):
    return input_exampe_generator(self.csv_path)

TRAIN_FILE = '../data/train.csv'
train_dataset = SBERTInputDataset(TRAIN_FILE)
train_dataloader = DataLoader(train_dataset, batch_size=32)

# %% [markdown]
# ## Train the model
# - SBERT Training

# %%
from sentence_transformers import SentenceTransformer, losses, fit_mixin
import os
from datasets import Dataset, DatasetDict

model = SentenceTransformer('all-MiniLM-L6-v2')
train_loss = losses.CosineSimilarityLoss(model)

# disable wandb enronement
os.environ["WANDB_DISABLED"] = "true"
os.environ["WANDB_MODE"] = "offline"
os.environ["WANDB_API_KEY"] = "disabled"

# quick fix to resolve the name error
fit_mixin.Dataset = Dataset
fit_mixin.DatasetDict = DatasetDict

# automatically pick GPU if available
model.fit(
    train_objectives=[(train_dataloader, train_loss)],
    epochs=EPOCHS,
    warmup_steps=int(0.1*EPOCHS),
    show_progress_bar=True
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[23], line 18
#      15 fit_mixin.DatasetDict = DatasetDict
#      17 # automatically pick GPU if available
# ---> 18 model.fit(
#      19     train_objectives=[(train_dataloader, train_loss)],
#      20     epochs=EPOCHS,
#      21     warmup_steps=int(0.1*EPOCHS),
#      22     show_progress_bar=True
#      23 )
#
# File ~/Documents/python/schema_matcher/.venv/lib/python3.13/site-packages/sentence_transformers/fit_mixin.py:321, in FitMixin.fit(self, train_objectives, evaluator, epochs, steps_per_epoch, scheduler, warmup_steps, optimizer_class, optimizer_params, weight_decay, evaluation_steps, output_path, save_best_model, max_grad_norm, use_amp, callback, show_progress_bar, checkpoint_path, checkpoint_save_steps, checkpoint_save_total_limit, resume_from_checkpoint)
#     315 # Transformers renamed `evaluation_strategy` to `eval_strategy` in v4.41.0
#     316 eval_strategy_key = (
#     317     "eval_strategy"
#     318     if version.parse(transformers.__version__) >= version.parse("4.41.0")
#     319     else "evaluation_strategy"
#     320 )
# --> 321 args = SentenceTransformerTrainingArguments(
#     322     output_dir=checkpoint_path or _default_checkpoint_dir(),
#     323     batch_sampler=batch_sampler,
#     324     multi_dataset_batch_sampler=MultiDatasetBatchSamplers.ROUND_ROBIN,
#     325     per_device_train_batch_size=batch_size,
#     326     per_device_eval_batch_size=batch_size,
#     327     num_train_epochs=epochs,
#     328     max_steps=max_steps,
#     329     **{
#     330         eval_strategy_key: "steps" if evaluation_steps is not None and evaluation_steps > 0 else "no",
#     331     },
#     332     eval_steps=evaluation_steps,
#     333     max_grad_norm=max_grad_norm,
#     334     fp16=use_amp,
#     335     disable_tqdm=not show_progress_bar,
#     336     save_strategy="steps" if checkpoint_path is not None else "no",
#     337     save_steps=checkpoint_save_steps,
#     338     save_total_limit=checkpoint_save_total_limit,
#     339 )
#     341 if steps_per_epoch is None or steps_per_epoch == 0:
#     342     steps_per_epoch = min([len(train_dataset) // batch_size for train_dataset in train_dataset_dict.values()])
#
# File <string>:138, in __init__(self, output_dir, overwrite_output_dir, do_train, do_eval, do_predict, eval_strategy, prediction_loss_only, per_device_train_batch_size, per_device_eval_batch_size, per_gpu_train_batch_size, per_gpu_eval_batch_size, gradient_accumulation_steps, eval_accumulation_steps, eval_delay, torch_empty_cache_steps, learning_rate, weight_decay, adam_beta1, adam_beta2, adam_epsilon, max_grad_norm, num_train_epochs, max_steps, lr_scheduler_type, lr_scheduler_kwargs, warmup_ratio, warmup_steps, log_level, log_level_replica, log_on_each_node, logging_dir, logging_strategy, logging_first_step, logging_steps, logging_nan_inf_filter, save_strategy, save_steps, save_total_limit, save_safetensors, save_on_each_node, save_only_model, restore_callback_states_from_checkpoint, no_cuda, use_cpu, use_mps_device, seed, data_seed, jit_mode_eval, use_ipex, bf16, fp16, fp16_opt_level, half_precision_backend, bf16_full_eval, fp16_full_eval, tf32, local_rank, ddp_backend, tpu_num_cores, tpu_metrics_debug, debug, dataloader_drop_last, eval_steps, dataloader_num_workers, dataloader_prefetch_factor, past_index, run_name, disable_tqdm, remove_unused_columns, label_names, load_best_model_at_end, metric_for_best_model, greater_is_better, ignore_data_skip, fsdp, fsdp_min_num_params, fsdp_config, fsdp_transformer_layer_cls_to_wrap, accelerator_config, deepspeed, label_smoothing_factor, optim, optim_args, adafactor, group_by_length, length_column_name, report_to, ddp_find_unused_parameters, ddp_bucket_cap_mb, ddp_broadcast_buffers, dataloader_pin_memory, dataloader_persistent_workers, skip_memory_metrics, use_legacy_prediction_loop, push_to_hub, resume_from_checkpoint, hub_model_id, hub_strategy, hub_token, hub_private_repo, hub_always_push, hub_revision, gradient_checkpointing, gradient_checkpointing_kwargs, include_inputs_for_metrics, include_for_metrics, eval_do_concat_batches, fp16_backend, push_to_hub_model_id, push_to_hub_organization, push_to_hub_token, mp_parameters, auto_find_batch_size, full_determinism, torchdynamo, ray_scope, ddp_timeout, torch_compile, torch_compile_backend, torch_compile_mode, include_tokens_per_second, include_num_input_tokens_seen, neftune_noise_alpha, optim_target_modules, batch_eval_metrics, eval_on_start, use_liger_kernel, liger_kernel_config, eval_use_gather_object, average_tokens_across_devices, prompts, batch_sampler, multi_dataset_batch_sampler, router_mapping, learning_rate_mapping)
#
# File ~/Documents/python/schema_matcher/.venv/lib/python3.13/site-packages/sentence_transformers/training_args.py:247, in SentenceTransformerTrainingArguments.__post_init__(self)
#     246 def __post_init__(self):
# --> 247     super().__post_init__()
#     249     self.batch_sampler = (
#     250         BatchSamplers(self.batch_sampler) if isinstance(self.batch_sampler, str) else self.batch_sampler
#     251     )
#     252     self.multi_dataset_batch_sampler = (
#     253         MultiDatasetBatchSamplers(self.multi_dataset_batch_sampler)
#     254         if isinstance(self.multi_dataset_batch_sampler, str)
#     255         else self.multi_dataset_batch_sampler
#     256     )
#
# File ~/Documents/python/schema_matcher/.venv/lib/python3.13/site-packages/transformers/training_args.py:1793, in TrainingArguments.__post_init__(self)
#    1791 # Initialize device before we proceed
#    1792 if self.framework == "pt" and is_torch_available():
# -> 1793     self.device
#    1795 # Disable average tokens when using single device
#    1796 if self.average_tokens_across_devices:
#
# File ~/Documents/python/schema_matcher/.venv/lib/python3.13/site-packages/transformers/training_args.py:2322, in TrainingArguments.device(self)
#    2318 """
#    2319 The device used by this process.
#    2320 """
#    2321 requires_backends(self, ["torch"])
# -> 2322 return self._setup_devices
#
# File ~/Documents/python/schema_matcher/.venv/lib/python3.13/site-packages/transformers/utils/generic.py:76, in cached_property.__get__(self, obj, objtype)
#      74 cached = getattr(obj, attr, None)
#      75 if cached is None:
# ---> 76     cached = self.fget(obj)
#      77     setattr(obj, attr, cached)
#      78 return cached
#
# File ~/Documents/python/schema_matcher/.venv/lib/python3.13/site-packages/transformers/training_args.py:2192, in TrainingArguments._setup_devices(self)
#    2190 if not is_sagemaker_mp_enabled():
#    2191     if not is_accelerate_available():
# -> 2192         raise ImportError(
#    2193             f"Using the `Trainer` with `PyTorch` requires `accelerate>={ACCELERATE_MIN_VERSION}`: "
#    2194             f"Please run `pip install transformers[torch]` or `pip install 'accelerate>={ACCELERATE_MIN_VERSION}'`"
#    2195         )
#    2196 # We delay the init of `PartialState` to the end for clarity
#    2197 accelerator_state_kwargs: dict[str, Any] = {"enabled": True, "use_configured_state": False}
#
# ImportError: Using the `Trainer` with `PyTorch` requires `accelerate>=0.26.0`: Please run `pip install transformers[torch]` or `pip install 'accelerate>=0.26.0'`

# %% [markdown]
# ## Save the model

# %%
model.save('output/sbert-finetuned-model')

# %%
# !zip -r output.zip output/

from google.colab import files

files.download('output.zip')
# Out:
#   adding: output/ (stored 0%)
#   adding: output/sbert-finetuned-model/ (stored 0%)
#   adding: output/sbert-finetuned-model/1_Pooling/ (stored 0%)
#   adding: output/sbert-finetuned-model/1_Pooling/config.json (deflated 57%)
#   adding: output/sbert-finetuned-model/special_tokens_map.json (deflated 80%)
#   adding: output/sbert-finetuned-model/2_Normalize/ (stored 0%)
#   adding: output/sbert-finetuned-model/config_sentence_transformers.json (deflated 35%)
#   adding: output/sbert-finetuned-model/config.json (deflated 48%)
#   adding: output/sbert-finetuned-model/tokenizer_config.json (deflated 73%)
#   adding: output/sbert-finetuned-model/tokenizer.json (deflated 71%)
#   adding: output/sbert-finetuned-model/sentence_bert_config.json (deflated 4%)
#   adding: output/sbert-finetuned-model/modules.json (deflated 62%)
#   adding: output/sbert-finetuned-model/vocab.txt (deflated 53%)
#   adding: output/sbert-finetuned-model/README.md (deflated 68%)
#   adding: output/sbert-finetuned-model/model.safetensors (deflated 8%)

# %% [markdown]
# ## Use the Model

# %%
! unzip output.zip
# Out:
# Archive:  output.zip
#    creating: output/
#    creating: output/sbert-finetuned-model/
#    creating: output/sbert-finetuned-model/1_Pooling/
#   inflating: output/sbert-finetuned-model/1_Pooling/config.json
#   inflating: output/sbert-finetuned-model/special_tokens_map.json
#    creating: output/sbert-finetuned-model/2_Normalize/
#   inflating: output/sbert-finetuned-model/config_sentence_transformers.json
#   inflating: output/sbert-finetuned-model/config.json
#   inflating: output/sbert-finetuned-model/tokenizer_config.json
#   inflating: output/sbert-finetuned-model/tokenizer.json
#   inflating: output/sbert-finetuned-model/sentence_bert_config.json
#   inflating: output/sbert-finetuned-model/modules.json
#   inflating: output/sbert-finetuned-model/vocab.txt
#   inflating: output/sbert-finetuned-model/README.md
#   inflating: output/sbert-finetuned-model/model.safetensors

# %% [markdown]
# ## Evaluate the model

# %%
from sklearn.metrics import confusion_matrix, f1_score, log_loss
import pandas as pd
import torch
import torch.nn.functional as F
from sentence_transformers import SentenceTransformer


device = 'cuda' if torch.cuda.is_available() else 'cpu'
model_path = '../model/output/sbert-finetuned-model'

model = SentenceTransformer(model_path)

def cosine_similarity(x, y):
  x = F.normalize(x, p=2, dim=1) # p=2 Euclidien distance
  y = F.normalize(y, p=2, dim=1)
  return F.cosine_similarity(x, y, dim=1)


def evaluate_model(model, test_file, return_df = False):
  df = pd.read_csv(test_file, engine='python')
  sentences_1 = df.question1.tolist()
  sentences_2 = df.question2.tolist()

  encoded_1 = model.encode(
      sentences_1,
      batch_size=32,
      show_progress_bar=True,
      normalize_embeddings=True,
      convert_to_tensor=True,
      device=device
      )

  encoded_2 = model.encode(
      sentences_2,
      batch_size=32,
      show_progress_bar=True,
      normalize_embeddings=True,
      convert_to_tensor=True,
      device=device
      )

  similarity_scores = cosine_similarity(
      encoded_1,
      encoded_2
      )

  df['similarity_scores'] = similarity_scores.tolist()

  df['clculated_similarity'] = df.apply(
      lambda x: 1 if x['similarity_scores'] > 0.75 else 0,
      axis=1
  )

  cm = confusion_matrix(
      df['is_duplicate'],
      df['clculated_similarity'],
      normalize= 'true'
      )
  print(f'confusion metircs: {cm}')

  F1 = f1_score(df['is_duplicate'], df['clculated_similarity'])
  print(f'F1 Score: {F1}')

  lg = log_loss(df['is_duplicate'], df['clculated_similarity'])
  print(f'Log Loss: {lg}')

  if return_df:
      return df

def calculate_similarity(model, sentence_1, sentence_2):
  encoded_1 = model.encode(
      sentence_1,
      batch_size=32,
      show_progress_bar=True,
      normalize_embeddings=True,
      convert_to_tensor=True,
      device=device
      )

  encoded_2 = model.encode(
      sentence_2,
      batch_size=32,
      show_progress_bar=True,
      normalize_embeddings=True,
      convert_to_tensor=True,
      device=device
      )
  similarity_scores = cosine_similarity(
      encoded_1,
      encoded_2
      )
  return similarity_scores.tolist()

def predict_duplicates(model, file):
  df = pd.read_csv(file, engine='python')
  df['similarity_scores'] = df.apply(
      lambda x: calculate_similarity(
          model,
          x['question1'],
          x['question2']
      ),
      axis=1
  )
  df['clculated_similarity'] = df.apply(
      lambda x: 1 if x['similarity_scores'] > 0.75 else 0,
      axis=1
  )
  return df

# df = evaluate_model(model, '../data/train.csv', return_df=True)
# df = predict_duplicates(model, 'test.csv')
# df.head()

# %% [markdown]
# ## Wrong prediction
# - Most of the wrong predictions are due to mislabelled examples
# - The 'is_duplicate' labels are not correct
#     - What is the ideal life after retirement? (question 1)
#     - What's life after retirement?
#     - 'is_duplicate' flag for this is 0. However, the questions seem to have similar meaning

# %%
df_wrong = df.loc[
    df['clculated_similarity'] != df['is_duplicate']
    ]

# %%
df.columns
# Out:
# Index(['id', 'qid1', 'qid2', 'question1', 'question2', 'is_duplicate',
#        'similarity_scores', 'clculated_similarity'],
#       dtype='object')

# %%
df_wrong.loc[
     df['clculated_similarity'] == 1
    ]
# Out:
#             id    qid1    qid2  \
# 41          41      83      84
# 139        139     279     280
# 202        202     405     406
# 277        277     554     555
# 298        298     596     597
# ...        ...     ...     ...
# 404114  404114  537757  537758
# 404167  404167  537817   15196
# 404222  404222  211594  523550
# 404256  404256   89818  537904
# 404289  404289  537932  537933
#
#                                                 question1  \
# 41      When can I expect my Cognizant confirmation mail?
# 139              What is the ideal life after retirement?
# 202       What's the best way to start learning robotics?
# 277                               How do most people die?
# 298     On what online platforms can I post ads for be...
# ...                                                   ...
# 404114       Where can I buy this dress? Is it expensive?
# 404167  If you could ask every human presently alive o...
# 404222                How can I make money in travelling?
# 404256  What are some of the most common questions ask...
# 404289              What is like to have sex with cousin?
#
#                                                 question2  is_duplicate  \
# 41         When can I expect Cognizant confirmation mail?             0
# 139                         What's life after retirement?             0
# 202     What is the best way to start robotics? Which ...             0
# 277                                    How do people die?             0
# 298     What online platforms can I post ads for beer ...             0
# ...                                                   ...           ...
# 404114                        Where can I buy this dress?             0
# 404167  If you could get now instantly and completely ...             0
# 404222  Is there any way you can make money from trave...             0
# 404256  What are the most common questions asked in in...             0
# 404289      What is it like to have sex with your cousin?             0
#
#         similarity_scores  clculated_similarity
# 41               0.971432                     1
# 139              0.868934                     1
# 202              0.849427                     1
# 277              0.890599                     1
# 298              0.996689                     1
# ...                   ...                   ...
# 404114           0.769026                     1
# 404167           0.830214                     1
# 404222           0.957303                     1
# 404256           0.959023                     1
# 404289           0.940674                     1
#
# [6156 rows x 8 columns]

# %% [markdown]
# ## Retrieving similar questions
# - ANN (Approximate Nearest Neighbour)
# - faiss (implementation by Facebook
# - Observations
#   - Some of the answers were good
#   - Some answers need improvements like
#     - Similarity between How do I read and find my YouTube comments? And how can I see all of my comments on Quora? found to be 0.9244135618209839
#  - further actions
#    - Change the loss function to `ConstrastiveLoss`

# %%
## find the match
import pandas as pd
from sentence_transformers import SentenceTransformer
import faiss
import numpy as np
import torch

device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = SentenceTransformer("../model/output/sbert-finetuned-model")
df = pd.read_csv('../data/train.csv', engine='python')

sentences_1 = df['question1'].tolist()
sentences_2 = df['question2'].tolist()


encoded1 = model.encode(
    sentences_1,
    batch_size=32,
    show_progress_bar=True,
    normalize_embeddings=True,
    convert_to_numpy=True,
    device=device
)
encoded2 = model.encode(
    sentences_2,
    batch_size=32,
    show_progress_bar=True,
    normalize_embeddings=True,
    convert_to_numpy=True,
    device=device
)

faiss.normalize_L2(encoded1)
faiss.normalize_L2(encoded2)

index = faiss.IndexFlatIP(encoded2.shape[1])
index.add(encoded2)

top_k = 5
similarites, indices = index.search(encoded1, top_k)
# Out:
# Batches:   0%|          | 0/12635 [00:00<?, ?it/s]
# /home/aneesh/python/schema_matcher/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1762: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Batches:   0%|          | 0/12635 [00:00<?, ?it/s]

# %%
similarites
# Out:
# array([[0.91227645, 0.8604805 , 0.8574519 , 0.8574519 , 0.84151256],
#        [0.8410276 , 0.6551413 , 0.61047506, 0.5974746 , 0.5974746 ],
#        [0.78315544, 0.7647015 , 0.71803963, 0.71803963, 0.71803963],
#        ...,
#        [0.74668044, 0.7255267 , 0.6535923 , 0.6329106 , 0.6018275 ],
#        [0.70431125, 0.701547  , 0.6977883 , 0.674984  , 0.6730344 ],
#        [0.9722142 , 0.91270566, 0.8314768 , 0.8136778 , 0.7995485 ]],
#       dtype=float32)

# %%
indices
# Out:
# array([[     0, 330730, 178514,  59733, 245368],
#        [263614,      1,  86052, 133496, 131477],
#        [269902, 127219, 257764, 147891,   1918],
#        ...,
#        [340794, 404287, 257235, 177369, 160305],
#        [ 71510, 292255,  69877, 318344, 328232],
#        [404289,  83668,  44714, 253035, 269078]])

# %%
for index in range(30):
    sim_q = []
    for i, s in zip(indices[index], similarites[index]):
        if s > .75:
            sim_q.append(f"{df['question2'][i]} (similarity:{s})")
        else:
            break
    if len(sim_q) > 0:
        print(f"question: \n{df['question1'][index]}")
        print('----------------------------------')
        print('similar questions')
        for item in sim_q:
            print(item)
        print('------------------------------------')
# Out:
# question:
# What is the step by step guide to invest in share market in india?
# ----------------------------------
# similar questions
# How do I invest in mutual funds in India? (similarity:0.9152430295944214)
# How do I invest in mutual funds in India? (similarity:0.9152430295944214)
# How do I publish a book in India? (similarity:0.9151650667190552)
# How do I invest money in the stock markets of India? (similarity:0.905360221862793)
# What are some good ways to invest money for a short period of time in India? (similarity:0.8961689472198486)
# ------------------------------------
# question:
# How can I be a good geologist?
# ----------------------------------
# similar questions
# What should I do to be a great geologist? (similarity:0.982363224029541)
# ------------------------------------
# question:
# When do you use シ instead of し?
# ----------------------------------
# similar questions
# When do you use シ instead of し? (similarity:0.9999998807907104)
# ------------------------------------
# question:
# How do I read and find my YouTube comments?
# ----------------------------------
# similar questions
# How can I see all my Youtube comments? (similarity:0.9619821310043335)
# How can I see all of my comments on Quora? (similarity:0.9244135618209839)
# How could I see my YouTube liked comments? (similarity:0.884782075881958)
# How could I see my YouTube liked comments? (similarity:0.8847820162773132)
# How do I view my past Instagram comments? (similarity:0.872404932975769)
# ------------------------------------
# question:
# What can make Physics easy to learn?
# ----------------------------------
# similar questions
# What can make Physics easy to learn? (similarity:0.9999998807907104)
# How can you make physics easy to learn? (similarity:0.9058026075363159)
# How can you make physics easy to learn? (similarity:0.9058026075363159)
# How can I make physics easy? (similarity:0.9020506143569946)
# ------------------------------------
# question:
# What was your first sexual experience like?
# ----------------------------------
# similar questions
# What was your first sexual experience? (similarity:0.9940319657325745)
# What was your first sexual experience? (similarity:0.9940317869186401)
# What is your first sexual experience? (similarity:0.9852901697158813)
# What was your first sex experience? (similarity:0.9838485717773438)
# What was your first sex experience? (similarity:0.983848512172699)
# ------------------------------------
# question:
# What are the laws to change your status from a student visa to a green card in the US, how do they compare to the immigration laws in Canada?
# ----------------------------------
# similar questions
# What are the laws to change your status from a student visa to a green card in the US, how do they compare to the immigration laws in Canada? (similarity:1.0000001192092896)
# ------------------------------------
# question:
# What would a Trump presidency mean for current international master’s students on an F1 visa?
# ----------------------------------
# similar questions
# What would a Trump presidency mean for current international master’s students on an F1 visa? (similarity:1.000000238418579)
# What would a Trump presidency mean for current international master’s students on an F1 visa? (similarity:1.000000238418579)
# Will the Trump factor affect the admission of international students in the USA? (similarity:0.9781230688095093)
# Will the Trump factor affect the admission of international students in the USA? (similarity:0.9781230688095093)
# Will the Trump factor affect the admission of international students in the USA? (similarity:0.9781230688095093)
# ------------------------------------
# question:
# What does manipulation mean?
# ----------------------------------
# similar questions
# What does manipulation means? (similarity:0.9928522109985352)
# ------------------------------------
# question:
# Why are so many Quora users posting questions that are readily answered on Google?
# ----------------------------------
# similar questions
# Why do people ask questions on Quora that are easily to find answers too on Google? (similarity:0.9911946058273315)
# Why do people ask questions on Quora that are easily to find answers too on Google? (similarity:0.9911946058273315)
# Why do people ask questions on Quora that are easily to find answers too on Google? (similarity:0.9911946058273315)
# Why do people ask questions on Quora that are easily to find answers too on Google? (similarity:0.9911946058273315)
# Why do people ask questions on Quora that are easily to find answers too on Google? (similarity:0.9911946058273315)
# ------------------------------------
# question:
# Which is the best digital marketing institution in banglore?
# ----------------------------------
# similar questions
# Which is the best digital marketing institution in banglore? (similarity:1.0000001192092896)
# Which one is the best event management companies in Banglore? (similarity:0.9621754884719849)
# Which is the best Java training company in Banglore? (similarity:0.9594588279724121)
# Which is the best CAT coaching centre in banglore? (similarity:0.9585096836090088)
# Which is the best GATE coaching center in Banglore? (similarity:0.9541904926300049)
# ------------------------------------
# question:
# Why do rockets look white?
# ----------------------------------
# similar questions
# Why are rockets and boosters painted white? (similarity:0.8417171239852905)
# Why are rockets and boosters painted white? (similarity:0.841717004776001)
# Why are rockets and boosters painted white? (similarity:0.841717004776001)
# Why are airplanes commonly painted white? (similarity:0.7911177277565002)
# Why are airplanes commonly painted white? (similarity:0.7911177277565002)
# ------------------------------------
# question:
# What's causing someone to be jealous?
# ----------------------------------
# similar questions
# Why do people become jealous? (similarity:0.889076828956604)
# Why do people feel jealousy? (similarity:0.8533147573471069)
# Why do people feel jealousy? (similarity:0.8533147573471069)
# Why do you feel jealous? (similarity:0.8038127422332764)
# Why do people feel envy? (similarity:0.7532132267951965)
# ------------------------------------
# question:
# What are the questions should not ask on Quora?
# ----------------------------------
# similar questions
# What kind of questions should not be asked on Quora? (similarity:0.9743360280990601)
# What sort of questions should NOT be asked on Quora? (similarity:0.9630916714668274)
# What sort of questions should NOT be asked on Quora? (similarity:0.9630916714668274)
# What questions should you not ask on Quora, even anonymously? (similarity:0.9474884867668152)
# What are some questions that shouldn't be asked on Quora? (similarity:0.9440841674804688)
# ------------------------------------
# question:
# What are some tips on making it through the job interview process at Medicines?
# ----------------------------------
# similar questions
# What are some tips on making it through the job interview process at Medicines? (similarity:1.0)
# What are some tips on making it through the job interview process at Medicines? (similarity:1.0)
# What are some things new employees should know going into their first day at Medicines? (similarity:0.9056910276412964)
# What are some things new employees should know going into their first day at Medicines? (similarity:0.9056910276412964)
# What is the typical career path for someone who becomes a professor in medicine? (similarity:0.7807435989379883)
# ------------------------------------
# question:
# What is web application?
# ----------------------------------
# similar questions
# What is web application? (similarity:1.000000238418579)
# What is web app? (similarity:0.9172930717468262)
# What are the Android applications? (similarity:0.8394162654876709)
# What is Google app? (similarity:0.7861676216125488)
# What is actually LTE? (similarity:0.771676242351532)
# ------------------------------------
# question:
# Does society place too much importance on sports?
# ----------------------------------
# similar questions
# Why is India so bad at sports? (similarity:0.8297595381736755)
# Why are so many people so fanatically, foaming-at-the-mouth crazy about sports? (similarity:0.7837557196617126)
# How can corporate social responsibility be used for the promotion of sports in India? (similarity:0.7812120914459229)
# What is the meaning of discrimination in sports? (similarity:0.7674292325973511)
# What are some adjectives I can use to describe sports? (similarity:0.7623130083084106)
# ------------------------------------
# question:
# What is best way to make money online?
# ----------------------------------
# similar questions
# What is best way to make money online? (similarity:1.0000001192092896)
# What is best way to make money online? (similarity:1.0)
# What is best way to make money online? (similarity:1.0)
# What is best way to make money online? (similarity:1.0)
# What is best way to make money online? (similarity:1.0)
# ------------------------------------
# question:
# How should I prepare for CA final law?
# ----------------------------------
# similar questions
# How should I prepare for CA final law? (similarity:1.0000001192092896)
# What is the best way to prepare for CA final law and audit? (similarity:0.9873505234718323)
# What is the best way to prepare for CA final law and audit? (similarity:0.9873505234718323)
# What is the best way to prepare for CA final law and audit? (similarity:0.9873505234718323)
# What is the best way to prepare for CA final law and audit? (similarity:0.9873505234718323)
# ------------------------------------

# %%
indices[0]
# Out:
# array([202369, 111062, 156698, 399128, 234556])

# %%
from sklearn.metrics.pairwise import cosine_similarity
s1 = model.encode(df.loc[0, 'question1'], convert_to_numpy=True)
s2 = model.encode(df.loc[156698, 'question2'], convert_to_numpy=True)
cosine_similarity(s1.reshape(1, -1), s2.reshape(1, -1))
# Out:
# /home/aneesh/python/schema_matcher/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1762: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# array([[0.915165]], dtype=float32)
